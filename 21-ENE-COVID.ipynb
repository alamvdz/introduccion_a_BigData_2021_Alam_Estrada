# %%
import pandas as pd
#Seaborn es para graficar y hacer comparaciones
import seaborn as sns
#Graficar
from matplotlib import pyplot as plt
# %matplotlib inline
df = pd.read_csv('https://datautmexample.s3.amazonaws.com/COVID-19_Case_Surveillance_Public_Use_Data.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# 0          2020/11/10  2020/11/10         NaN  Laboratory-confirmed case
# 1          2020/11/14  2020/11/10  2020/11/10  Laboratory-confirmed case
# 2          2020/11/19  2020/11/10  2020/11/09  Laboratory-confirmed case
# 3          2020/11/14  2020/11/10         NaN  Laboratory-confirmed case
# 4          2020/11/13  2020/11/10  2020/11/10  Laboratory-confirmed case
# ...               ...         ...         ...                        ...
# 8405074    2020/10/22         NaN         NaN              Probable Case
# 8405075    2020/10/25         NaN         NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN         NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN         NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN         NaN  Laboratory-confirmed case
#
#              sex      age_group Race and ethnicity (combined)  hosp_yn  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8405079 entries, 0 to 8405078
# Data columns (total 11 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   cdc_report_dt                  object
#  1   pos_spec_dt                    object
#  2   onset_dt                       object
#  3   current_status                 object
#  4   sex                            object
#  5   age_group                      object
#  6   Race and ethnicity (combined)  object
#  7   hosp_yn                        object
#  8   icu_yn                         object
#  9   death_yn                       object
#  10  medcond_yn                     object
# dtypes: object(11)
# memory usage: 705.4+ MB

# %%
df.cdc_report_dt.unique()
# Out:
# array(['2020/11/10', '2020/11/14', '2020/11/19', '2020/11/13',
#        '2020/11/17', '2020/11/09', '2020/11/15', '2020/11/06',
#        '2020/11/18', '2020/11/11', '2020/11/16', '2020/11/02',
#        '2020/11/07', '2020/11/08', '2020/11/12', '2020/11/05',
#        '2020/10/28', '2020/11/03', '2020/08/18', '2020/10/20',
#        '2020/11/01', '2020/11/04', '2020/10/25', '2020/10/24',
#        '2020/09/05', '2020/10/27', '2020/10/31', '2020/10/05',
#        '2020/10/29', '2020/10/30', '2020/05/28', '2020/10/01',
#        '2020/10/11', '2020/10/17', '2020/09/08', '2020/07/11',
#        '2020/10/26', '2020/10/10', '2020/09/25', '2020/10/18',
#        '2020/10/08', '2020/10/16', '2020/09/24', '2020/10/14',
#        '2020/05/15', '2020/10/23', '2020/09/26', '2020/10/09',
#        '2020/08/24', '2020/10/19', '2020/04/27', '2020/08/31',
#        '2020/09/15', '2020/10/04', '2020/09/18', '2020/09/27',
#        '2020/09/14', '2020/08/22', '2020/09/16', '2020/09/30',
# ...

# %%
df.pos_spec_dt	.unique()
# Out:
# array(['2020/11/10', '2020/11/11', '2020/11/12', '2020/11/13',
#        '2020/11/14', '2020/11/15', '2020/11/16', '2020/11/17',
#        '2020/11/18', '2020/11/19', '2020/11/20', '2020/11/21',
#        '2020/11/22', '2020/11/23', '2020/11/24', '2020/11/25',
#        '2020/11/26', '2020/11/27', '2020/11/28', '2020/11/29',
#        '2020/11/30', '2020/12/01', '2020/12/02', nan, '2020/01/16',
#        '2020/01/17', '2020/01/22', '2020/01/23', '2020/01/29',
#        '2020/02/02', '2020/02/06', '2020/02/09', '2020/02/21',
#        '2020/02/22', '2020/02/29', '2020/03/01', '2020/03/02',
#        '2020/03/03', '2020/03/04', '2020/03/05', '2020/03/06',
#        '2020/03/07', '2020/03/08', '2020/03/09', '2020/03/10',
#        '2020/03/11', '2020/03/12', '2020/03/25', '2020/05/08',
#        '2020/05/09', '2020/05/10', '2020/05/11', '2020/05/12',
#        '2020/05/13', '2020/05/14', '2020/05/15', '2020/05/16',
#        '2020/05/17', '2020/05/18', '2020/05/19', '2020/05/20',
# ...

# %%
df.describe()
# Out:
#        cdc_report_dt pos_spec_dt    onset_dt             current_status  \
# count        8405079     2870789     4395957                    8405079
# unique           321         313         338                          2
# top       2020/06/24  2020/11/09  2020/11/02  Laboratory-confirmed case
# freq          155857       50595       49527                    7910118
#
#             sex      age_group Race and ethnicity (combined)  hosp_yn  \
# count   8405061        8404990                       8405072  8405079
# unique        5             10                             9        4
# top      Female  20 - 29 Years                       Unknown       No
# freq    4340898        1635264                       2781176  3502556
#
#          icu_yn death_yn medcond_yn
# count   8405079  8405079    8405079
# unique        4        4          4
# top     Missing       No    Missing
# freq    6178281  3690813    6063390

# %%
relation = df[['sex','age_group', 'death_yn']]

# %%
relation.head(2500)
# Out:
#        sex      age_group death_yn
# 0     Male  10 - 19 Years       No
# 1     Male  10 - 19 Years       No
# 2     Male  10 - 19 Years       No
# 3     Male  10 - 19 Years       No
# 4     Male  10 - 19 Years       No
# ...    ...            ...      ...
# 2495  Male  10 - 19 Years  Missing
# 2496  Male  10 - 19 Years       No
# 2497  Male  10 - 19 Years  Missing
# 2498  Male  10 - 19 Years       No
# 2499  Male  10 - 19 Years       No
#
# [2500 rows x 3 columns]

# %%
df.tail(4)
# Out:
#         cdc_report_dt pos_spec_dt onset_dt             current_status  \
# 8405075    2020/10/25         NaN      NaN  Laboratory-confirmed case
# 8405076    2020/07/18         NaN      NaN  Laboratory-confirmed case
# 8405077    2020/11/19         NaN      NaN  Laboratory-confirmed case
# 8405078    2020/11/03         NaN      NaN  Laboratory-confirmed case
#
#              sex      age_group Race and ethnicity (combined)  hosp_yn  \
# 8405075  Missing  30 - 39 Years                       Unknown  Missing
# 8405076  Missing  30 - 39 Years                       Unknown  Missing
# 8405077  Missing  30 - 39 Years                       Unknown  Missing
# 8405078  Missing  30 - 39 Years                       Unknown       No
#
#           icu_yn death_yn medcond_yn
# 8405075  Missing  Missing    Missing
# 8405076  Missing  Missing    Missing
# 8405077  Missing  Missing    Missing
# 8405078  Unknown       No    Missing

# %%
portiondata = relation.head(200)

# %%
sns.distplot(df.cdc_report_dt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-6da8103df6e0> in <module>
# ----> 1 sns.distplot(df.cdc_report_dt)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     177
#     178     # Make a a 1-d float array
# --> 179     a = np.asarray(a, np.float)
#     180     if a.ndim > 1:
#     181         a = a.squeeze()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/series.py in __array__(self, dtype)
#     752               dtype='datetime64[ns]')
# ...
